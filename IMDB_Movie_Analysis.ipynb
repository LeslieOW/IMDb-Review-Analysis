# %% [markdown]
# ##  IMDb Review Analysis
#
# #### By Leslie Wagwa
#
#
# The IMDb dataset contains movies and several features associated with each movie such as the title and the reviews.

# %% [markdown]
# ### Importing libraries

# %%
#importing libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading the dataset

# %%
#loading the data
df = pd.read_csv("IMDB_data.zip")

# %%
#first five data-points
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
#last five data-points
df.tail()
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                 Movie_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944           U   97 min
# 999            The 39 Steps          1935           U   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# ...

# %%
df1.tail()
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#dimensipn ofthe data
df.shape
# Out:
# (1000, 16)

# %%
#information regareding the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
#descriptie summary ofthe dataset
df.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %%
#handling missing values
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
#filling missing values

df['Certificate'] = df['Certificate'].fillna(df['Certificate'].mode()[0])
df['Meta_score'] = df['Meta_score'].fillna(df['Meta_score'].median())
df['Gross'] = df['Gross'].fillna(df['Gross'].mode()[0])

# %%
#confirming that there are no missing  values in the dataset
df.isnull().sum()
# Out:
# Poster_Link      0
# Series_Title     0
# Released_Year    0
# Certificate      0
# Runtime          0
# Genre            0
# IMDB_Rating      0
# Overview         0
# Meta_score       0
# Director         0
# Star1            0
# Star2            0
# Star3            0
# Star4            0
# No_of_Votes      0
# Gross            0
# dtype: int64

# %%
#renaming column
df = df.rename(columns={"Series_Title": "Movie_Title"})

# %% [markdown]
# Obtaining an overview of the dataset

# %%
#summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Movie_Title    1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    1000 non-null   object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     1000 non-null   float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          1000 non-null   object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
#Obtaining the mean review rating by genre
Mean_Rate_by_Genre = df.groupby(by='Genre')['IMDB_Rating'].mean()
Mean_Rate_by_Genre
# Out:
# Genre
# Action, Adventure               8.180000
# Action, Adventure, Biography    7.900000
# Action, Adventure, Comedy       7.910000
# Action, Adventure, Crime        7.600000
# Action, Adventure, Drama        8.150000
#                                   ...
# Mystery, Romance, Thriller      8.300000
# Mystery, Sci-Fi, Thriller       7.800000
# Mystery, Thriller               7.977778
# Thriller                        7.800000
# Western                         8.350000
# Name: IMDB_Rating, Length: 202, dtype: float64

# %%
Mean_Rate_by_Genre.max()
# Out:
# 8.5

# %% [markdown]
# #### Insights
# The movie genre which had the highest rating had a mean rating of 8.5

# %%
#plotting
plt.plot(Mean_Rate_by_Genre[:20])
plt.xticks(rotation=90)
plt.title("Mean Review Rating by Genre");

# %% [markdown]
# #### Finding correlation

# %%
df.corr()
# Out:
#              IMDB_Rating  Meta_score  No_of_Votes
# IMDB_Rating     1.000000     0.25865     0.494979
# Meta_score      0.258650     1.00000    -0.026940
# No_of_Votes     0.494979    -0.02694     1.000000

# %%
#plotting a heatmap
cm = df.corr()
tcm = cm.index

sns.heatmap(df[tcm].corr(), annot=True);

# %%
#plotting numerical features
numerical_attributes = ['IMDB_Rating', 'Meta_score', 'No_of_Votes']
df[numerical_attributes].hist(figsize = (15, 6), color = 'blue', 
                                edgecolor = 'red', layout = (2, 2));

# %%
#data description
df.describe(include = ['O'])
# Out:
#                                               Poster_Link Movie_Title  \
# count                                                1000        1000
# unique                                               1000         999
# top     https://m.media-amazon.com/images/M/MV5BMDFkYT...    Drishyam
# freq                                                    1           2
#
#        Released_Year Certificate  Runtime  Genre  \
# count           1000        1000     1000   1000
# unique           100          16      140    202
# top             2014           U  100 min  Drama
# freq              32         335       23     85
#
#                                                  Overview          Director  \
# count                                                1000              1000
# unique                                               1000               548
# top     Two imprisoned men bond over a number of years...  Alfred Hitchcock
# ...

# %%
#obtaining top voted movies
top_voted = df.sort_values(['No_of_Votes'], ascending = False)

# %% [markdown]
# #### Top voted movies

# %%
#creating a bar plot
fig,axs=plt.subplots(figsize=(15,5))
g=sns.barplot(x=top_voted['Movie_Title'][:7],
              y=top_voted['No_of_Votes'][:7], palette = 'hls')
g.set_title("Top Voted Movies", weight = "bold")
plt.show();

# %% [markdown]
# #### Top voted movie rating

# %%
fig,axs=plt.subplots(figsize=(15,5))
g=sns.barplot(x=top_voted['Movie_Title'][:5],y=top_voted['IMDB_Rating'][:7], palette = 'husl')
g.set_title("IMDB Rating of top voted movies", weight = "bold")
plt.show()

# %% [markdown]
# #### Top voted movies metascores

# %%
ig,axs=plt.subplots(figsize=(15,5))
g=sns.barplot(x=top_voted['Movie_Title'][:7],y=top_voted['Meta_score'][:7], palette = 'husl')
g.set_title("Metascore of top rated movies", weight = "bold")
plt.show()

# %% [markdown]
# #### Maximum movies released in:

# %%
fig,axs=plt.subplots(figsize=(20,5))
g=sns.barplot(x=df['Released_Year'].value_counts()[:10].index,y=df['Released_Year'].value_counts()[:10])
g.set_title("Maximum Series released in-", weight = "bold")
g.set_xlabel("Years")
plt.show();

# %% [markdown]
# #### Most popular Directors

# %%
#creating a lineplot
fig,axs=plt.subplots(figsize=(20,5))
g=sns.lineplot(x=df['Director'].value_counts()[:10].index,y=df['Released_Year'].value_counts()[:10])
g.set_title("Mostly Occurred Directors", weight = "bold")
g.set_xlabel("Directors", weight = "bold")
plt.show()

# %%
#bar plot for most popular directors
fig,axs=plt.subplots(figsize=(20,5))
g=sns.barplot(x=df['Director'].value_counts()[:10].index,y=df['Director'].value_counts()[:10])
g.set_title("Mostly Occurred Directors", weight = "bold")
g.set_xlabel("Directors", weight = "bold")
plt.show()

# %% [markdown]
# ### Runtime of the movies

# %%
import re
duration=[]
for x in df["Runtime"]:
    p=re.compile('\d+')
    j=p.findall(x)
    if len(j)==2:
        duration.append(int(j[1])-int(j[0])+1)
    else:
        duration.append(int(j[0])+1)
df['duration']=duration

# %%
df['duration'].head()
# Out:
# 0    143
# 1    176
# 2    153
# 3    203
# 4     97
# Name: duration, dtype: int64

# %% [markdown]
# ##### The distribution for movie duration

# %%
#kde plot
fig,axs=plt.subplots(figsize=(20,5))
g=sns.kdeplot(df['duration'])
g.set_title("Time Duration of movies", weight = "bold");

# %% [markdown]
# #### Checking for values in Certificate column

# %%
df['Certificate'].isnull().sum()
# Out:
# 0

# %%
#visualizing
certificates=df[df['Certificate']!='Not Rated']['Certificate']
fig,axs=plt.subplots(figsize=(20,5))
g=sns.countplot(certificates)
g.set_title("Count of Certificates provided", weight = "bold")
plt.show();
# Out:
# C:\anaconda\ANACONDA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### IMDB Rating Distribution

# %%
#plotting
fig,axs=plt.subplots(figsize=(20,5))
g=sns.distplot(df['IMDB_Rating'],bins=30, color='purple')
g.set_title("Distribution of Ratings", weight = "bold")
plt.show()
# Out:
# C:\anaconda\ANACONDA\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#obtaining maximum movie rating
df['IMDB_Rating'].max()
# Out:
# 9.3

# %%
#obtaining minimum movie rating
df['IMDB_Rating'].min()
# Out:
# 7.6

# %%
df.columns
# Out:
# Index(['Poster_Link', 'Movie_Title', 'Released_Year', 'Certificate', 'Runtime',
#        'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1',
#        'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross', 'duration'],
#       dtype='object')

# %%
df.groupby(by='Movie_Title')['IMDB_Rating'].max()
# Out:
# Movie_Title
# (500) Days of Summer           7.7
# 12 Angry Men                   9.0
# 12 Years a Slave               8.1
# 1917                           8.3
# 2001: A Space Odyssey          8.3
#                               ...
# Zootopia                       8.0
# Zulu                           7.7
# Zwartboek                      7.7
# À bout de souffle              7.8
# Ôkami kodomo no Ame to Yuki    8.1
# Name: IMDB_Rating, Length: 999, dtype: float64

# %% [markdown]
# ### Top 10 Genres

# %%
from collections import Counter
genre=[]
for x in df['Genre']:
    for y in x.split(','):
        genre.append(y.strip().lower())

count=Counter(genre)
count=count.most_common()[:10]
x,y=map(list,zip(*count))

fig,axs=plt.subplots(figsize=(20,5))
g=sns.barplot(y,x)
g.set_ylabel("Genres", weight = "bold")
g.set_title("Top Ten Genres", weight = "bold")
plt.show()
# Out:
# C:\anaconda\ANACONDA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
